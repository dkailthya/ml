# %%
import pandas as pd
import numpy as np
np.random.seed(12345)
# %matplotlib inline
import seaborn as sns

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('https://query.data.world/s/ztpm4umva6g4fr54ls2dpaejssebfe', 
                 header=None, 
                 names=['claims', 'payments'])

# %%
df.plot(x=0, y=1, kind='scatter')

# %%
sns.lmplot('claims', 'payments', df)
